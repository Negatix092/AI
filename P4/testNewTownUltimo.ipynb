# %%
# %pip install deap
# %pip install geopy
# %pip install pyproj
# Out:
# Collecting deap
#   Downloading deap-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deap) (1.23.5)
# Installing collected packages: deap
# Successfully installed deap-1.4.1
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy) (2.0)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj) (2023.7.22)

# %% [markdown]
# # Definiciones

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from deap import base, creator, tools, algorithms
from pyproj import Proj
from geopy.distance import geodesic

# Definir las coordenadas de las ciudades
cities = {
    "Seattle": (47.608013, -122.335167),
    "Boise": (43.616616, -116.200886),
    "Everett": (47.967306, -122.201399),
    "Pendleton": (45.672075, -118.788597),
    "Biggs": (45.669846, -120.832841),
    "Portland": (45.520247, -122.674194),
    "Twin Falls": (42.570446, -114.460255),
    "Bend": (44.058173, -121.315310),
    "Spokane": (47.657193, -117.423510),
    "Grant Pass": (42.441561, -123.339336),
    "Burns": (43.586126, -119.054413),
    "Eugene": (44.050505, -123.095051),
    "Lakeview": (42.188772, -120.345792),
    "Missoula": (46.870105, -113.995267)
}

# Proyección cartográfica
projection = Proj(proj='aeqd', ellps='WGS84', datum='WGS84', lat_0=0, lon_0=0)

def project_coordinates(lon, lat):
    x, y = projection(lon, lat)
    return x, y

# Proyectar las coordenadas de las ciudades
projected_cities = {city: project_coordinates(lon, lat) for city, (lat, lon) in cities.items()}

# %% [markdown]
# # Función de Fitness y Configuraión del Algoritmo Genético

# %%
# Convertir índices a nombres de ciudades
def indices_to_cities(indices):
    return [list(cities.keys())[i] for i in indices]

def calculate_total_distance(indices):
    route = indices_to_cities(indices)
    total_distance = 0
    for i in range(len(route)):
        city_a = route[i]
        city_b = route[(i + 1) % len(route)]
        total_distance += geodesic(cities[city_a], cities[city_b]).kilometers
    return total_distance,


# Crear el objeto fitness y los individuos
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)


toolbox = base.Toolbox()

# Función para crear una ruta aleatoria
toolbox.register("indices", random.sample, range(len(cities)), len(cities))
toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.indices)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# Función de fitness
toolbox.register("evaluate", calculate_total_distance)

# Operadores genéticos
toolbox.register("select", tools.selTournament, tournsize=2)
toolbox.register("mate", tools.cxOrdered)
toolbox.register("mutate", tools.mutShuffleIndexes, indpb=1.0/len(cities))

# Crear la población inicial
population = toolbox.population(n=300)
# Out:
# /usr/local/lib/python3.10/dist-packages/deap/creator.py:185: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /usr/local/lib/python3.10/dist-packages/deap/creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "

# %% [markdown]
# # Algoritmo Genético

# %%
# Crear la población inicial
population_mu_lambda = toolbox.population(n=300)
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("avg", np.mean)
stats.register("min", np.min)

def print_generation_info(generation, population):
    best_ind = tools.selBest(population, 1)[0]
    print(f"**GENERATION**: {generation}")
    print("******************")
    if generation == 0:
        print("INITIAL RANDOM PATH AND DISTANCE:")
    else:
        print("PATH AND DISTANCE:")
    route = indices_to_cities(best_ind)
    print(" ==> ".join(route) + " ==> " + route[0])
    print(f"Fitness value: {best_ind.fitness.values[0]}")
    print("******************")

# Inicializa listas para almacenar datos de fitness
min_fitness_values_mu_lambda = []
avg_fitness_values_mu_lambda = []
generations_mu_lambda = range(200)

# Algoritmo genético eaMuCommaLambda
random.seed(42)
for gen in range(200):

    # Genera una nueva generación
    offspring_mu_lambda, logbook = algorithms.eaMuCommaLambda(population_mu_lambda, toolbox, mu=300, lambda_=300,
                                                              cxpb=0.90, mutpb=0.1, ngen=1, stats=stats,
                                                              halloffame=None, verbose=False)
    # Evalúa a los individuos con un fitness inválido
    invalid_ind_mu_lambda = [ind for ind in offspring_mu_lambda if not ind.fitness.valid]
    fitnesses_mu_lambda = map(toolbox.evaluate, invalid_ind_mu_lambda)
    for ind, fit in zip(invalid_ind_mu_lambda, fitnesses_mu_lambda):
        ind.fitness.values = fit

    # Actualiza la población
    population_mu_lambda = offspring_mu_lambda

    # Imprime la información de la generación
    print_generation_info(gen, population_mu_lambda)

    # Recolecta estadísticas
    record_mu_lambda = stats.compile(population_mu_lambda)
    print(record_mu_lambda)

    # Recolecta y almacena los datos de fitness
    min_fitness_values_mu_lambda.append(record_mu_lambda['min'])
    avg_fitness_values_mu_lambda.append(record_mu_lambda['avg'])
# Out:
# **GENERATION**: 0
# ******************
# INITIAL RANDOM PATH AND DISTANCE:
# Portland ==> Bend ==> Burns ==> Lakeview ==> Grant Pass ==> Seattle ==> Everett ==> Missoula ==> Pendleton ==> Boise ==> Twin Falls ==> Spokane ==> Eugene ==> Biggs ==> Portland
# Fitness value: 4559.741915047177
# ******************
# {'avg': 5908.856162388955, 'min': 4559.741915047177}
# **GENERATION**: 1
# ******************
# PATH AND DISTANCE:
# Portland ==> Burns ==> Everett ==> Seattle ==> Eugene ==> Grant Pass ==> Lakeview ==> Bend ==> Boise ==> Twin Falls ==> Missoula ==> Pendleton ==> Spokane ==> Biggs ==> Portland
# Fitness value: 4195.167707459125
# ******************
# {'avg': 5659.456552099705, 'min': 4195.167707459125}
# **GENERATION**: 2
# ******************
# PATH AND DISTANCE:
# Spokane ==> Seattle ==> Everett ==> Portland ==> Lakeview ==> Eugene ==> Burns ==> Twin Falls ==> Boise ==> Missoula ==> Bend ==> Grant Pass ==> Biggs ==> Pendleton ==> Spokane
# Fitness value: 4417.877074300559
# ******************
# {'avg': 5520.161375127165, 'min': 4417.877074300559}
# **GENERATION**: 3
# ******************
# PATH AND DISTANCE:
# Bend ==> Grant Pass ==> Eugene ==> Everett ==> Portland ==> Seattle ==> Spokane ==> Twin Falls ==> Boise ==> Missoula ==> Biggs ==> Pendleton ==> Lakeview ==> Burns ==> Bend
# Fitness value: 4423.157688171203
# ******************
# {'avg': 5386.927135996215, 'min': 4423.157688171203}
# **GENERATION**: 4
# ******************
# PATH AND DISTANCE:
# Portland ==> Seattle ==> Biggs ==> Everett ==> Pendleton ==> Missoula ==> Spokane ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Grant Pass ==> Eugene ==> Bend ==> Portland
# Fitness value: 4282.811175176407
# ******************
# {'avg': 5331.0043273397305, 'min': 4282.811175176407}
# **GENERATION**: 5
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Missoula ==> Boise ==> Grant Pass ==> Lakeview ==> Bend ==> Biggs ==> Eugene ==> Portland ==> Seattle ==> Everett ==> Spokane ==> Pendleton ==> Burns ==> Twin Falls
# Fitness value: 4051.9209963915546
# ******************
# {'avg': 5315.846368745353, 'min': 4051.9209963915546}
# **GENERATION**: 6
# ******************
# PATH AND DISTANCE:
# Burns ==> Lakeview ==> Grant Pass ==> Eugene ==> Portland ==> Biggs ==> Bend ==> Twin Falls ==> Spokane ==> Seattle ==> Everett ==> Pendleton ==> Missoula ==> Boise ==> Burns
# Fitness value: 4100.4450532861365
# ******************
# {'avg': 5330.577225867074, 'min': 4100.4450532861365}
# **GENERATION**: 7
# ******************
# PATH AND DISTANCE:
# Burns ==> Lakeview ==> Grant Pass ==> Eugene ==> Portland ==> Biggs ==> Bend ==> Twin Falls ==> Spokane ==> Seattle ==> Everett ==> Pendleton ==> Missoula ==> Boise ==> Burns
# Fitness value: 4100.4450532861365
# ******************
# {'avg': 5302.597322448064, 'min': 4100.4450532861365}
# **GENERATION**: 8
# ******************
# PATH AND DISTANCE:
# Burns ==> Lakeview ==> Grant Pass ==> Eugene ==> Portland ==> Biggs ==> Pendleton ==> Seattle ==> Spokane ==> Everett ==> Bend ==> Twin Falls ==> Boise ==> Missoula ==> Burns
# Fitness value: 4304.72979962805
# ******************
# {'avg': 5224.896601168431, 'min': 4304.72979962805}
# **GENERATION**: 9
# ******************
# PATH AND DISTANCE:
# Eugene ==> Bend ==> Portland ==> Everett ==> Seattle ==> Biggs ==> Boise ==> Twin Falls ==> Pendleton ==> Burns ==> Missoula ==> Spokane ==> Lakeview ==> Grant Pass ==> Eugene
# Fitness value: 4125.468900420037
# ******************
# {'avg': 5153.05105981809, 'min': 4125.468900420037}
# **GENERATION**: 10
# ******************
# PATH AND DISTANCE:
# Bend ==> Burns ==> Lakeview ==> Grant Pass ==> Eugene ==> Portland ==> Biggs ==> Twin Falls ==> Boise ==> Everett ==> Seattle ==> Spokane ==> Missoula ==> Pendleton ==> Bend
# Fitness value: 3931.612305727839
# ******************
# {'avg': 5060.210538881154, 'min': 3931.612305727839}
# **GENERATION**: 11
# ******************
# PATH AND DISTANCE:
# Burns ==> Portland ==> Bend ==> Everett ==> Seattle ==> Biggs ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Lakeview ==> Grant Pass ==> Eugene ==> Burns
# Fitness value: 4056.006203224871
# ******************
# {'avg': 4994.566546989853, 'min': 4056.006203224871}
# **GENERATION**: 12
# ******************
# PATH AND DISTANCE:
# Everett ==> Eugene ==> Grant Pass ==> Bend ==> Lakeview ==> Spokane ==> Missoula ==> Biggs ==> Pendleton ==> Boise ==> Twin Falls ==> Burns ==> Portland ==> Seattle ==> Everett
# Fitness value: 4227.519444498524
# ******************
# {'avg': 4959.824008178377, 'min': 4227.519444498524}
# **GENERATION**: 13
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Everett ==> Seattle ==> Portland ==> Grant Pass ==> Eugene ==> Bend ==> Lakeview ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Burns ==> Biggs ==> Pendleton
# Fitness value: 3740.5500066408154
# ******************
# {'avg': 4914.333444587313, 'min': 3740.5500066408154}
# **GENERATION**: 14
# ******************
# PATH AND DISTANCE:
# Portland ==> Burns ==> Bend ==> Biggs ==> Grant Pass ==> Eugene ==> Lakeview ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett ==> Seattle ==> Portland
# Fitness value: 3820.3906296865007
# ******************
# {'avg': 4906.796499940397, 'min': 3820.3906296865007}
# **GENERATION**: 15
# ******************
# PATH AND DISTANCE:
# Portland ==> Grant Pass ==> Eugene ==> Bend ==> Lakeview ==> Boise ==> Burns ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett ==> Seattle ==> Biggs ==> Portland
# Fitness value: 3677.4543550257445
# ******************
# {'avg': 4842.630542043908, 'min': 3677.4543550257445}
# **GENERATION**: 16
# ******************
# PATH AND DISTANCE:
# Portland ==> Grant Pass ==> Eugene ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Bend ==> Lakeview ==> Burns ==> Biggs ==> Pendleton ==> Everett ==> Seattle ==> Portland
# Fitness value: 3999.510409675613
# ******************
# {'avg': 4904.047865890826, 'min': 3999.510409675613}
# **GENERATION**: 17
# ******************
# PATH AND DISTANCE:
# Burns ==> Pendleton ==> Boise ==> Twin Falls ==> Spokane ==> Missoula ==> Seattle ==> Everett ==> Portland ==> Grant Pass ==> Eugene ==> Biggs ==> Bend ==> Lakeview ==> Burns
# Fitness value: 3933.0117692354775
# ******************
# {'avg': 4882.863829668603, 'min': 3933.0117692354775}
# **GENERATION**: 18
# ******************
# PATH AND DISTANCE:
# Burns ==> Pendleton ==> Boise ==> Twin Falls ==> Spokane ==> Missoula ==> Seattle ==> Everett ==> Portland ==> Grant Pass ==> Eugene ==> Biggs ==> Bend ==> Lakeview ==> Burns
# Fitness value: 3933.0117692354775
# ******************
# {'avg': 4918.574231032456, 'min': 3933.0117692354775}
# **GENERATION**: 19
# ******************
# PATH AND DISTANCE:
# Burns ==> Pendleton ==> Boise ==> Twin Falls ==> Lakeview ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Portland ==> Bend ==> Grant Pass ==> Eugene ==> Biggs ==> Burns
# Fitness value: 3984.850971598009
# ******************
# {'avg': 4862.935192854976, 'min': 3984.850971598009}
# **GENERATION**: 20
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Spokane ==> Missoula ==> Twin Falls ==> Lakeview ==> Boise ==> Burns ==> Seattle ==> Everett ==> Portland ==> Bend ==> Grant Pass ==> Eugene ==> Biggs ==> Pendleton
# Fitness value: 3949.4662893901095
# ******************
# {'avg': 4857.025695085918, 'min': 3949.4662893901095}
# **GENERATION**: 21
# ******************
# PATH AND DISTANCE:
# Bend ==> Grant Pass ==> Burns ==> Lakeview ==> Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Eugene ==> Portland ==> Biggs ==> Bend
# Fitness value: 3747.726452588253
# ******************
# {'avg': 4793.982672355151, 'min': 3747.726452588253}
# **GENERATION**: 22
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Biggs ==> Seattle ==> Everett ==> Portland ==> Eugene ==> Bend ==> Lakeview ==> Grant Pass ==> Pendleton
# Fitness value: 3533.1619058799724
# ******************
# {'avg': 4807.966821388335, 'min': 3533.1619058799724}
# **GENERATION**: 23
# ******************
# PATH AND DISTANCE:
# Biggs ==> Pendleton ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Seattle ==> Everett ==> Portland ==> Bend ==> Grant Pass ==> Lakeview ==> Eugene ==> Biggs
# Fitness value: 3645.6850777126515
# ******************
# {'avg': 4837.032606816767, 'min': 3645.6850777126515}
# **GENERATION**: 24
# ******************
# PATH AND DISTANCE:
# Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Grant Pass ==> Portland ==> Eugene ==> Bend ==> Biggs ==> Everett ==> Seattle ==> Pendleton ==> Spokane ==> Missoula
# Fitness value: 3349.0405377776688
# ******************
# {'avg': 4810.654905504238, 'min': 3349.0405377776688}
# **GENERATION**: 25
# ******************
# PATH AND DISTANCE:
# Seattle ==> Eugene ==> Burns ==> Portland ==> Grant Pass ==> Lakeview ==> Bend ==> Biggs ==> Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle
# Fitness value: 3891.005497525477
# ******************
# {'avg': 4841.983310137607, 'min': 3891.005497525477}
# **GENERATION**: 26
# ******************
# PATH AND DISTANCE:
# Boise ==> Burns ==> Lakeview ==> Pendleton ==> Bend ==> Grant Pass ==> Eugene ==> Seattle ==> Portland ==> Biggs ==> Everett ==> Spokane ==> Missoula ==> Twin Falls ==> Boise
# Fitness value: 3866.063435215643
# ******************
# {'avg': 4839.673177253547, 'min': 3866.063435215643}
# **GENERATION**: 27
# ******************
# PATH AND DISTANCE:
# Boise ==> Burns ==> Lakeview ==> Pendleton ==> Bend ==> Grant Pass ==> Eugene ==> Seattle ==> Portland ==> Biggs ==> Everett ==> Spokane ==> Missoula ==> Twin Falls ==> Boise
# Fitness value: 3866.063435215643
# ******************
# {'avg': 4853.140294333547, 'min': 3866.063435215643}
# **GENERATION**: 28
# ******************
# PATH AND DISTANCE:
# Eugene ==> Grant Pass ==> Lakeview ==> Boise ==> Twin Falls ==> Burns ==> Portland ==> Pendleton ==> Biggs ==> Seattle ==> Everett ==> Spokane ==> Missoula ==> Bend ==> Eugene
# Fitness value: 3910.972795361381
# ******************
# {'avg': 4848.892521717141, 'min': 3910.972795361381}
# **GENERATION**: 29
# ******************
# PATH AND DISTANCE:
# Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Grant Pass ==> Bend ==> Eugene ==> Everett ==> Seattle ==> Portland ==> Biggs ==> Pendleton ==> Spokane
# Fitness value: 3252.3941911671263
# ******************
# {'avg': 4829.713261627354, 'min': 3252.3941911671263}
# **GENERATION**: 30
# ******************
# PATH AND DISTANCE:
# Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Grant Pass ==> Bend ==> Eugene ==> Everett ==> Seattle ==> Portland ==> Biggs ==> Pendleton ==> Spokane
# Fitness value: 3252.3941911671263
# ******************
# {'avg': 4828.876577069989, 'min': 3252.3941911671263}
# **GENERATION**: 31
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Burns ==> Lakeview ==> Grant Pass ==> Bend ==> Eugene ==> Everett ==> Seattle ==> Portland ==> Biggs ==> Pendleton ==> Spokane ==> Missoula ==> Boise ==> Twin Falls
# Fitness value: 3334.3481658374744
# ******************
# {'avg': 4713.481997571255, 'min': 3334.3481658374744}
# **GENERATION**: 32
# ******************
# PATH AND DISTANCE:
# Burns ==> Bend ==> Biggs ==> Portland ==> Grant Pass ==> Lakeview ==> Eugene ==> Pendleton ==> Seattle ==> Everett ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns
# Fitness value: 3715.0620620460886
# ******************
# {'avg': 4716.858960452342, 'min': 3715.0620620460886}
# **GENERATION**: 33
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Eugene ==> Grant Pass ==> Bend ==> Portland ==> Biggs ==> Pendleton ==> Spokane ==> Everett ==> Seattle ==> Missoula ==> Twin Falls
# Fitness value: 3588.5147121236496
# ******************
# {'avg': 4711.013578280219, 'min': 3588.5147121236496}
# **GENERATION**: 34
# ******************
# PATH AND DISTANCE:
# Spokane ==> Everett ==> Seattle ==> Biggs ==> Eugene ==> Portland ==> Bend ==> Grant Pass ==> Lakeview ==> Boise ==> Twin Falls ==> Burns ==> Pendleton ==> Missoula ==> Spokane
# Fitness value: 3598.83509551393
# ******************
# {'avg': 4758.24550531034, 'min': 3598.83509551393}
# **GENERATION**: 35
# ******************
# PATH AND DISTANCE:
# Boise ==> Lakeview ==> Grant Pass ==> Bend ==> Eugene ==> Everett ==> Seattle ==> Portland ==> Burns ==> Pendleton ==> Biggs ==> Spokane ==> Missoula ==> Twin Falls ==> Boise
# Fitness value: 3752.8782363926102
# ******************
# {'avg': 4779.370416956337, 'min': 3752.8782363926102}
# **GENERATION**: 36
# ******************
# PATH AND DISTANCE:
# Boise ==> Lakeview ==> Grant Pass ==> Bend ==> Eugene ==> Everett ==> Seattle ==> Portland ==> Burns ==> Pendleton ==> Biggs ==> Spokane ==> Missoula ==> Twin Falls ==> Boise
# Fitness value: 3752.8782363926102
# ******************
# {'avg': 4733.065665381874, 'min': 3752.8782363926102}
# **GENERATION**: 37
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Seattle ==> Everett ==> Eugene ==> Grant Pass ==> Lakeview ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Burns ==> Bend ==> Portland ==> Biggs ==> Pendleton
# Fitness value: 3724.7030893448114
# ******************
# {'avg': 4690.643017719672, 'min': 3724.7030893448114}
# **GENERATION**: 38
# ******************
# PATH AND DISTANCE:
# Bend ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Portland ==> Everett ==> Seattle ==> Biggs ==> Lakeview ==> Burns ==> Eugene ==> Grant Pass ==> Bend
# Fitness value: 3786.871447922881
# ******************
# {'avg': 4710.421223741903, 'min': 3786.871447922881}
# **GENERATION**: 39
# ******************
# PATH AND DISTANCE:
# Everett ==> Seattle ==> Biggs ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Twin Falls ==> Boise ==> Missoula ==> Spokane ==> Burns ==> Bend ==> Pendleton ==> Everett
# Fitness value: 3661.508028680806
# ******************
# {'avg': 4651.643282800256, 'min': 3661.508028680806}
# **GENERATION**: 40
# ******************
# PATH AND DISTANCE:
# Eugene ==> Bend ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Portland ==> Grant Pass ==> Lakeview ==> Pendleton ==> Biggs ==> Eugene
# Fitness value: 3546.9821373760833
# ******************
# {'avg': 4614.10620250167, 'min': 3546.9821373760833}
# **GENERATION**: 41
# ******************
# PATH AND DISTANCE:
# Everett ==> Seattle ==> Portland ==> Bend ==> Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Biggs ==> Burns ==> Lakeview ==> Grant Pass ==> Eugene ==> Everett
# Fitness value: 3650.9818517336103
# ******************
# {'avg': 4660.138881495839, 'min': 3650.9818517336103}
# **GENERATION**: 42
# ******************
# PATH AND DISTANCE:
# Portland ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Seattle ==> Everett ==> Eugene ==> Portland
# Fitness value: 3337.365333955567
# ******************
# {'avg': 4713.806757141172, 'min': 3337.365333955567}
# **GENERATION**: 43
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Boise ==> Missoula ==> Spokane ==> Portland ==> Everett ==> Seattle ==> Biggs ==> Bend ==> Eugene ==> Pendleton ==> Burns ==> Grant Pass ==> Lakeview ==> Twin Falls
# Fitness value: 3934.946076870368
# ******************
# {'avg': 4758.562069579803, 'min': 3934.946076870368}
# **GENERATION**: 44
# ******************
# PATH AND DISTANCE:
# Portland ==> Bend ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Pendleton ==> Biggs ==> Lakeview ==> Grant Pass ==> Eugene ==> Portland
# Fitness value: 3440.799444351616
# ******************
# {'avg': 4731.732705434618, 'min': 3440.799444351616}
# **GENERATION**: 45
# ******************
# PATH AND DISTANCE:
# Everett ==> Seattle ==> Spokane ==> Missoula ==> Boise ==> Twin Falls ==> Burns ==> Bend ==> Lakeview ==> Grant Pass ==> Portland ==> Biggs ==> Pendleton ==> Eugene ==> Everett
# Fitness value: 3794.7445710294423
# ******************
# {'avg': 4690.342726107954, 'min': 3794.7445710294423}
# **GENERATION**: 46
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Burns ==> Lakeview ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Bend ==> Grant Pass ==> Eugene ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Pendleton
# Fitness value: 3762.918504100459
# ******************
# {'avg': 4697.656515022227, 'min': 3762.918504100459}
# **GENERATION**: 47
# ******************
# PATH AND DISTANCE:
# Burns ==> Lakeview ==> Biggs ==> Everett ==> Seattle ==> Pendleton ==> Twin Falls ==> Boise ==> Missoula ==> Spokane ==> Portland ==> Eugene ==> Grant Pass ==> Bend ==> Burns
# Fitness value: 3832.815365463123
# ******************
# {'avg': 4618.306641179638, 'min': 3832.815365463123}
# **GENERATION**: 48
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Boise ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Biggs ==> Pendleton ==> Eugene ==> Portland ==> Grant Pass ==> Bend ==> Burns ==> Lakeview ==> Twin Falls
# Fitness value: 3666.891539597954
# ******************
# {'avg': 4638.954326384478, 'min': 3666.891539597954}
# **GENERATION**: 49
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Eugene ==> Everett ==> Seattle ==> Portland ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Biggs ==> Pendleton
# Fitness value: 3757.1492141353856
# ******************
# {'avg': 4627.585123280988, 'min': 3757.1492141353856}
# **GENERATION**: 50
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Burns ==> Lakeview ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Portland ==> Bend ==> Grant Pass ==> Eugene ==> Biggs ==> Pendleton
# Fitness value: 3446.272651409873
# ******************
# {'avg': 4515.392733382944, 'min': 3446.272651409873}
# **GENERATION**: 51
# ******************
# PATH AND DISTANCE:
# Missoula ==> Spokane ==> Everett ==> Seattle ==> Biggs ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Boise ==> Twin Falls ==> Burns ==> Pendleton ==> Missoula
# Fitness value: 3402.1304797562307
# ******************
# {'avg': 4542.198805057191, 'min': 3402.1304797562307}
# **GENERATION**: 52
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Burns ==> Lakeview ==> Bend ==> Grant Pass ==> Eugene ==> Everett ==> Seattle ==> Biggs ==> Portland ==> Pendleton
# Fitness value: 3720.9378552783323
# ******************
# {'avg': 4542.045514103864, 'min': 3720.9378552783323}
# **GENERATION**: 53
# ******************
# PATH AND DISTANCE:
# Everett ==> Portland ==> Bend ==> Lakeview ==> Burns ==> Pendleton ==> Biggs ==> Grant Pass ==> Eugene ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett
# Fitness value: 3765.029132572381
# ******************
# {'avg': 4554.46649291373, 'min': 3765.029132572381}
# **GENERATION**: 54
# ******************
# PATH AND DISTANCE:
# Seattle ==> Everett ==> Biggs ==> Eugene ==> Portland ==> Bend ==> Lakeview ==> Grant Pass ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Pendleton ==> Spokane ==> Seattle
# Fitness value: 3673.331950468079
# ******************
# {'avg': 4555.589855263583, 'min': 3673.331950468079}
# **GENERATION**: 55
# ******************
# PATH AND DISTANCE:
# Portland ==> Eugene ==> Bend ==> Lakeview ==> Grant Pass ==> Biggs ==> Burns ==> Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Portland
# Fitness value: 3572.3107109177695
# ******************
# {'avg': 4534.085385186524, 'min': 3572.3107109177695}
# **GENERATION**: 56
# ******************
# PATH AND DISTANCE:
# Bend ==> Lakeview ==> Grant Pass ==> Biggs ==> Burns ==> Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Portland ==> Eugene ==> Bend
# Fitness value: 3572.3107109177695
# ******************
# {'avg': 4527.755490692876, 'min': 3572.3107109177695}
# **GENERATION**: 57
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Portland ==> Bend ==> Biggs ==> Pendleton
# Fitness value: 3555.8892081978897
# ******************
# {'avg': 4578.121008590042, 'min': 3555.8892081978897}
# **GENERATION**: 58
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Burns ==> Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Portland ==> Eugene ==> Biggs ==> Bend ==> Lakeview ==> Grant Pass
# Fitness value: 3555.949569876151
# ******************
# {'avg': 4568.407872080951, 'min': 3555.949569876151}
# **GENERATION**: 59
# ******************
# PATH AND DISTANCE:
# Lakeview ==> Burns ==> Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Portland ==> Eugene ==> Biggs ==> Bend ==> Grant Pass ==> Lakeview
# Fitness value: 3393.233091478599
# ******************
# {'avg': 4645.5386354268385, 'min': 3393.233091478599}
# **GENERATION**: 60
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Lakeview ==> Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Portland ==> Eugene ==> Biggs ==> Burns ==> Bend ==> Grant Pass
# Fitness value: 3656.8233288778133
# ******************
# {'avg': 4633.181457594357, 'min': 3656.8233288778133}
# **GENERATION**: 61
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Burns ==> Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Portland ==> Eugene ==> Biggs ==> Bend ==> Lakeview ==> Grant Pass
# Fitness value: 3555.949569876151
# ******************
# {'avg': 4571.031422483903, 'min': 3555.949569876151}
# **GENERATION**: 62
# ******************
# PATH AND DISTANCE:
# Lakeview ==> Pendleton ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Eugene ==> Grant Pass ==> Bend ==> Lakeview
# Fitness value: 3510.761752800325
# ******************
# {'avg': 4540.3867338514565, 'min': 3510.761752800325}
# **GENERATION**: 63
# ******************
# PATH AND DISTANCE:
# Biggs ==> Pendleton ==> Lakeview ==> Burns ==> Twin Falls ==> Boise ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Portland ==> Eugene ==> Grant Pass ==> Bend ==> Biggs
# Fitness value: 3460.127668157909
# ******************
# {'avg': 4540.932851090825, 'min': 3460.127668157909}
# **GENERATION**: 64
# ******************
# PATH AND DISTANCE:
# Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Pendleton ==> Spokane ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Eugene ==> Bend ==> Grant Pass ==> Lakeview
# Fitness value: 3410.99055542993
# ******************
# {'avg': 4536.300659004038, 'min': 3410.99055542993}
# **GENERATION**: 65
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Burns ==> Lakeview ==> Pendleton ==> Twin Falls ==> Boise ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Biggs ==> Portland ==> Bend ==> Eugene ==> Grant Pass
# Fitness value: 3660.6666669540227
# ******************
# {'avg': 4547.5907103991785, 'min': 3660.6666669540227}
# **GENERATION**: 66
# ******************
# PATH AND DISTANCE:
# Eugene ==> Biggs ==> Lakeview ==> Burns ==> Twin Falls ==> Boise ==> Missoula ==> Spokane ==> Pendleton ==> Everett ==> Seattle ==> Portland ==> Bend ==> Grant Pass ==> Eugene
# Fitness value: 3580.2541696614194
# ******************
# {'avg': 4592.78171803192, 'min': 3580.2541696614194}
# **GENERATION**: 67
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Portland ==> Everett ==> Seattle ==> Grant Pass ==> Eugene ==> Bend ==> Burns ==> Lakeview ==> Boise ==> Twin Falls
# Fitness value: 3452.712446903246
# ******************
# {'avg': 4606.6378427398795, 'min': 3452.712446903246}
# **GENERATION**: 68
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Portland ==> Everett ==> Seattle ==> Grant Pass ==> Eugene ==> Bend ==> Burns ==> Lakeview ==> Boise ==> Twin Falls
# Fitness value: 3452.712446903246
# ******************
# {'avg': 4631.515759403291, 'min': 3452.712446903246}
# **GENERATION**: 69
# ******************
# PATH AND DISTANCE:
# Spokane ==> Seattle ==> Everett ==> Pendleton ==> Biggs ==> Portland ==> Grant Pass ==> Eugene ==> Bend ==> Burns ==> Lakeview ==> Boise ==> Twin Falls ==> Missoula ==> Spokane
# Fitness value: 3434.4257867973142
# ******************
# {'avg': 4580.676499430185, 'min': 3434.4257867973142}
# **GENERATION**: 70
# ******************
# PATH AND DISTANCE:
# Spokane ==> Seattle ==> Everett ==> Pendleton ==> Biggs ==> Portland ==> Grant Pass ==> Eugene ==> Bend ==> Burns ==> Lakeview ==> Boise ==> Twin Falls ==> Missoula ==> Spokane
# Fitness value: 3434.4257867973142
# ******************
# {'avg': 4570.891693738777, 'min': 3434.4257867973142}
# **GENERATION**: 71
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Portland ==> Everett ==> Seattle ==> Grant Pass ==> Eugene ==> Bend ==> Burns ==> Lakeview ==> Boise ==> Twin Falls
# Fitness value: 3452.712446903246
# ******************
# {'avg': 4557.531565453543, 'min': 3452.712446903246}
# **GENERATION**: 72
# ******************
# PATH AND DISTANCE:
# Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Portland ==> Everett ==> Seattle ==> Eugene ==> Bend ==> Burns ==> Grant Pass ==> Lakeview ==> Boise ==> Twin Falls ==> Missoula
# Fitness value: 3525.4543796393036
# ******************
# {'avg': 4537.485408263218, 'min': 3525.4543796393036}
# **GENERATION**: 73
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Biggs ==> Portland ==> Everett ==> Seattle ==> Grant Pass ==> Eugene ==> Lakeview ==> Bend ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton
# Fitness value: 3505.873474791976
# ******************
# {'avg': 4490.945921413299, 'min': 3505.873474791976}
# **GENERATION**: 74
# ******************
# PATH AND DISTANCE:
# Biggs ==> Everett ==> Seattle ==> Grant Pass ==> Eugene ==> Portland ==> Bend ==> Burns ==> Lakeview ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs
# Fitness value: 3528.491691865884
# ******************
# {'avg': 4531.008972938148, 'min': 3528.491691865884}
# **GENERATION**: 75
# ******************
# PATH AND DISTANCE:
# Everett ==> Seattle ==> Biggs ==> Pendleton ==> Grant Pass ==> Lakeview ==> Portland ==> Eugene ==> Bend ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett
# Fitness value: 3644.05876328317
# ******************
# {'avg': 4510.071382053734, 'min': 3644.05876328317}
# **GENERATION**: 76
# ******************
# PATH AND DISTANCE:
# Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Biggs ==> Bend ==> Pendleton ==> Boise
# Fitness value: 3433.302350202017
# ******************
# {'avg': 4495.763404213197, 'min': 3433.302350202017}
# **GENERATION**: 77
# ******************
# PATH AND DISTANCE:
# Portland ==> Everett ==> Seattle ==> Eugene ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Portland
# Fitness value: 3252.2505678333646
# ******************
# {'avg': 4469.911568702027, 'min': 3252.2505678333646}
# **GENERATION**: 78
# ******************
# PATH AND DISTANCE:
# Seattle ==> Portland ==> Biggs ==> Burns ==> Grant Pass ==> Eugene ==> Bend ==> Lakeview ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett ==> Seattle
# Fitness value: 3525.529647556012
# ******************
# {'avg': 4434.6802928971265, 'min': 3525.529647556012}
# **GENERATION**: 79
# ******************
# PATH AND DISTANCE:
# Eugene ==> Grant Pass ==> Bend ==> Biggs ==> Burns ==> Lakeview ==> Twin Falls ==> Boise ==> Pendleton ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Portland ==> Eugene
# Fitness value: 3509.3646106165424
# ******************
# {'avg': 4449.724788713164, 'min': 3509.3646106165424}
# **GENERATION**: 80
# ******************
# PATH AND DISTANCE:
# Seattle ==> Pendleton ==> Portland ==> Biggs ==> Lakeview ==> Grant Pass ==> Eugene ==> Bend ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle
# Fitness value: 3510.8491187611367
# ******************
# {'avg': 4478.013574556631, 'min': 3510.8491187611367}
# **GENERATION**: 81
# ******************
# PATH AND DISTANCE:
# Biggs ==> Portland ==> Grant Pass ==> Eugene ==> Bend ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Pendleton ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Biggs
# Fitness value: 3436.6711517892886
# ******************
# {'avg': 4517.881714019518, 'min': 3436.6711517892886}
# **GENERATION**: 82
# ******************
# PATH AND DISTANCE:
# Biggs ==> Lakeview ==> Grant Pass ==> Eugene ==> Bend ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Portland ==> Seattle ==> Everett ==> Biggs
# Fitness value: 3413.951203099378
# ******************
# {'avg': 4515.321595263219, 'min': 3413.951203099378}
# **GENERATION**: 83
# ******************
# PATH AND DISTANCE:
# Seattle ==> Everett ==> Biggs ==> Eugene ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Portland ==> Pendleton ==> Seattle
# Fitness value: 3676.73148963797
# ******************
# {'avg': 4499.497196500712, 'min': 3676.73148963797}
# **GENERATION**: 84
# ******************
# PATH AND DISTANCE:
# Everett ==> Pendleton ==> Biggs ==> Lakeview ==> Grant Pass ==> Eugene ==> Bend ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Portland ==> Seattle ==> Everett
# Fitness value: 3581.2224081173895
# ******************
# {'avg': 4533.016806811474, 'min': 3581.2224081173895}
# **GENERATION**: 85
# ******************
# PATH AND DISTANCE:
# Everett ==> Pendleton ==> Biggs ==> Lakeview ==> Grant Pass ==> Eugene ==> Bend ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Portland ==> Seattle ==> Everett
# Fitness value: 3581.2224081173895
# ******************
# {'avg': 4535.555443543473, 'min': 3581.2224081173895}
# **GENERATION**: 86
# ******************
# PATH AND DISTANCE:
# Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett ==> Seattle ==> Eugene ==> Grant Pass ==> Lakeview ==> Bend ==> Biggs ==> Portland ==> Burns
# Fitness value: 3553.4429430302357
# ******************
# {'avg': 4594.243600523103, 'min': 3553.4429430302357}
# **GENERATION**: 87
# ******************
# PATH AND DISTANCE:
# Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett ==> Seattle ==> Eugene ==> Grant Pass ==> Lakeview ==> Bend ==> Biggs ==> Portland ==> Burns
# Fitness value: 3553.4429430302357
# ******************
# {'avg': 4590.113069624016, 'min': 3553.4429430302357}
# **GENERATION**: 88
# ******************
# PATH AND DISTANCE:
# Portland ==> Everett ==> Seattle ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Pendleton ==> Spokane ==> Biggs ==> Bend ==> Portland
# Fitness value: 3580.789300219708
# ******************
# {'avg': 4565.526487876506, 'min': 3580.789300219708}
# **GENERATION**: 89
# ******************
# PATH AND DISTANCE:
# Portland ==> Everett ==> Seattle ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Pendleton ==> Spokane ==> Biggs ==> Bend ==> Portland
# Fitness value: 3580.789300219708
# ******************
# {'avg': 4569.767869195662, 'min': 3580.789300219708}
# **GENERATION**: 90
# ******************
# PATH AND DISTANCE:
# Portland ==> Everett ==> Seattle ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Pendleton ==> Spokane ==> Biggs ==> Bend ==> Portland
# Fitness value: 3580.789300219708
# ******************
# {'avg': 4581.768910048523, 'min': 3580.789300219708}
# **GENERATION**: 91
# ******************
# PATH AND DISTANCE:
# Lakeview ==> Bend ==> Boise ==> Burns ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Portland ==> Everett ==> Seattle ==> Eugene ==> Grant Pass ==> Lakeview
# Fitness value: 3702.133065005926
# ******************
# {'avg': 4574.459930969315, 'min': 3702.133065005926}
# **GENERATION**: 92
# ******************
# PATH AND DISTANCE:
# Eugene ==> Portland ==> Bend ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Pendleton ==> Biggs ==> Lakeview ==> Grant Pass ==> Eugene
# Fitness value: 3468.572290555344
# ******************
# {'avg': 4508.957322400991, 'min': 3468.572290555344}
# **GENERATION**: 93
# ******************
# PATH AND DISTANCE:
# Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Biggs ==> Portland ==> Pendleton ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns
# Fitness value: 3286.679121528025
# ******************
# {'avg': 4514.73249772139, 'min': 3286.679121528025}
# **GENERATION**: 94
# ******************
# PATH AND DISTANCE:
# Burns ==> Twin Falls ==> Boise ==> Biggs ==> Pendleton ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Portland ==> Eugene ==> Grant Pass ==> Bend ==> Lakeview ==> Burns
# Fitness value: 3516.708440445723
# ******************
# {'avg': 4455.717902055815, 'min': 3516.708440445723}
# **GENERATION**: 95
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Portland ==> Eugene ==> Biggs ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Pendleton ==> Boise ==> Twin Falls
# Fitness value: 3443.7839521252517
# ******************
# {'avg': 4449.74738096791, 'min': 3443.7839521252517}
# **GENERATION**: 96
# ******************
# PATH AND DISTANCE:
# Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Portland ==> Biggs ==> Eugene ==> Grant Pass ==> Lakeview ==> Bend ==> Burns ==> Pendleton ==> Boise
# Fitness value: 3398.76826114217
# ******************
# {'avg': 4392.400492664005, 'min': 3398.76826114217}
# **GENERATION**: 97
# ******************
# PATH AND DISTANCE:
# Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Portland ==> Biggs ==> Eugene ==> Grant Pass ==> Lakeview ==> Bend ==> Burns ==> Pendleton ==> Boise
# Fitness value: 3398.76826114217
# ******************
# {'avg': 4347.611546319393, 'min': 3398.76826114217}
# **GENERATION**: 98
# ******************
# PATH AND DISTANCE:
# Missoula ==> Spokane ==> Everett ==> Seattle ==> Biggs ==> Portland ==> Pendleton ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula
# Fitness value: 3286.679121528025
# ******************
# {'avg': 4312.452129838246, 'min': 3286.679121528025}
# **GENERATION**: 99
# ******************
# PATH AND DISTANCE:
# Spokane ==> Everett ==> Seattle ==> Biggs ==> Portland ==> Pendleton ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane
# Fitness value: 3286.679121528025
# ******************
# {'avg': 4221.94986651388, 'min': 3286.679121528025}
# **GENERATION**: 100
# ******************
# PATH AND DISTANCE:
# Missoula ==> Spokane ==> Pendleton ==> Seattle ==> Everett ==> Portland ==> Bend ==> Biggs ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula
# Fitness value: 3320.36115244323
# ******************
# {'avg': 4237.785911832578, 'min': 3320.36115244323}
# **GENERATION**: 101
# ******************
# PATH AND DISTANCE:
# Missoula ==> Spokane ==> Everett ==> Seattle ==> Pendleton ==> Biggs ==> Bend ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula
# Fitness value: 3233.5578816352586
# ******************
# {'avg': 4231.930406091636, 'min': 3233.5578816352586}
# **GENERATION**: 102
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Portland ==> Biggs ==> Eugene ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Pendleton ==> Boise ==> Twin Falls
# Fitness value: 3381.2230467894087
# ******************
# {'avg': 4241.73946828291, 'min': 3381.2230467894087}
# **GENERATION**: 103
# ******************
# PATH AND DISTANCE:
# Spokane ==> Seattle ==> Everett ==> Portland ==> Bend ==> Biggs ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane
# Fitness value: 3408.3271182543654
# ******************
# {'avg': 4180.366494996698, 'min': 3408.3271182543654}
# **GENERATION**: 104
# ******************
# PATH AND DISTANCE:
# Seattle ==> Everett ==> Pendleton ==> Portland ==> Biggs ==> Eugene ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle
# Fitness value: 3465.524112670362
# ******************
# {'avg': 4197.038484773726, 'min': 3465.524112670362}
# **GENERATION**: 105
# ******************
# PATH AND DISTANCE:
# Seattle ==> Everett ==> Portland ==> Eugene ==> Pendleton ==> Biggs ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle
# Fitness value: 3425.0408234623415
# ******************
# {'avg': 4242.666669902349, 'min': 3425.0408234623415}
# **GENERATION**: 106
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Bend ==> Seattle ==> Everett ==> Biggs ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton
# Fitness value: 3325.960871305435
# ******************
# {'avg': 4214.420582514516, 'min': 3325.960871305435}
# **GENERATION**: 107
# ******************
# PATH AND DISTANCE:
# Seattle ==> Everett ==> Portland ==> Bend ==> Biggs ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Seattle
# Fitness value: 3320.3611524432295
# ******************
# {'avg': 4275.108046806694, 'min': 3320.3611524432295}
# **GENERATION**: 108
# ******************
# PATH AND DISTANCE:
# Seattle ==> Portland ==> Pendleton ==> Biggs ==> Eugene ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Twin Falls ==> Boise ==> Missoula ==> Spokane ==> Everett ==> Seattle
# Fitness value: 3421.4725915914264
# ******************
# {'avg': 4294.695738254978, 'min': 3421.4725915914264}
# **GENERATION**: 109
# ******************
# PATH AND DISTANCE:
# Seattle ==> Everett ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Twin Falls ==> Boise ==> Pendleton ==> Missoula ==> Spokane ==> Biggs ==> Seattle
# Fitness value: 3402.52845521605
# ******************
# {'avg': 4209.209091228675, 'min': 3402.52845521605}
# **GENERATION**: 110
# ******************
# PATH AND DISTANCE:
# Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Pendleton ==> Biggs ==> Bend ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Portland
# Fitness value: 3392.9074328304255
# ******************
# {'avg': 4245.084109340211, 'min': 3392.9074328304255}
# **GENERATION**: 111
# ******************
# PATH AND DISTANCE:
# Everett ==> Portland ==> Biggs ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Pendleton ==> Twin Falls ==> Boise ==> Missoula ==> Spokane ==> Seattle ==> Everett
# Fitness value: 3350.1811026182218
# ******************
# {'avg': 4147.531499948069, 'min': 3350.1811026182218}
# **GENERATION**: 112
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Portland ==> Biggs ==>
# ******************
# PATH AND DISTANCE:
# Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Pendleton ==> Biggs ==> Bend ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise
# Fitness value: 3261.3307278389857
# ******************
# {'avg': 3860.1806721991643, 'min': 3261.3307278389857}
# **GENERATION**: 135
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Seattle ==> Everett ==> Biggs ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls
# Fitness value: 3172.331710183213
# ******************
# {'avg': 3790.461003655537, 'min': 3172.331710183213}
# **GENERATION**: 136
# ******************
# PATH AND DISTANCE:
# Spokane ==> Pendleton ==> Everett ==> Seattle ==> Biggs ==> Bend ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane
# Fitness value: 3221.306498901934
# ******************
# {'avg': 3830.148453163554, 'min': 3221.306498901934}
# **GENERATION**: 137
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Bend ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton
# Fitness value: 3127.1011088613054
# ******************
# {'avg': 3809.396757100321, 'min': 3127.1011088613054}
# **GENERATION**: 138
# ******************
# PATH AND DISTANCE:
# Spokane ==> Pendleton ==> Everett ==> Seattle ==> Biggs ==> Bend ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane
# Fitness value: 3221.306498901934
# ******************
# {'avg': 3820.5066157469278, 'min': 3221.306498901934}
# **GENERATION**: 139
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Biggs ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Pendleton ==> Boise ==> Twin Falls
# Fitness value: 3218.9387131734998
# ******************
# {'avg': 3782.870092684604, 'min': 3218.9387131734998}
# **GENERATION**: 140
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Biggs ==> Portland ==> Eugene ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Pendleton ==> Boise ==> Twin Falls
# Fitness value: 3254.3955470443857
# ******************
# {'avg': 3772.0975553955323, 'min': 3254.3955470443857}
# **GENERATION**: 141
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Eugene ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton
# Fitness value: 3109.555894508543
# ******************
# {'avg': 3713.352692437996, 'min': 3109.555894508543}
# **GENERATION**: 142
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Everett ==> Seattle ==> Biggs ==> Portland ==> Eugene ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton
# Fitness value: 3194.2024274369774
# ******************
# {'avg': 3653.4325406371136, 'min': 3194.2024274369774}
# **GENERATION**: 143
# ******************
# PATH AND DISTANCE:
# Everett ==> Seattle ==> Biggs ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett
# Fitness value: 3158.745593566091
# ******************
# {'avg': 3571.800411715037, 'min': 3158.745593566091}
# **GENERATION**: 144
# ******************
# PATH AND DISTANCE:
# Everett ==> Seattle ==> Biggs ==> Portland ==> Eugene ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett
# Fitness value: 3194.202427436977
# ******************
# {'avg': 3612.367732149153, 'min': 3194.202427436977}
# **GENERATION**: 145
# ******************
# PATH AND DISTANCE:
# Everett ==> Seattle ==> Biggs ==> Portland ==> Eugene ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett
# Fitness value: 3194.202427436977
# ******************
# {'avg': 3672.9847301915675, 'min': 3194.202427436977}
# **GENERATION**: 146
# ******************
# PATH AND DISTANCE:
# Everett ==> Seattle ==> Biggs ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett
# Fitness value: 3218.9387131734993
# ******************
# {'avg': 3720.0049898511575, 'min': 3218.9387131734993}
# **GENERATION**: 147
# ******************
# PATH AND DISTANCE:
# Everett ==> Seattle ==> Biggs ==> Portland ==> Eugene ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett
# Fitness value: 3194.202427436977
# ******************
# {'avg': 3794.7632160376734, 'min': 3194.202427436977}
# **GENERATION**: 148
# ******************
# PATH AND DISTANCE:
# Seattle ==> Biggs ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett ==> Seattle
# Fitness value: 3158.7455935660905
# ******************
# {'avg': 3756.8611052065244, 'min': 3158.7455935660905}

# %%
# Hall of Fame para la versión sin elitismo
hof_no_elitism = tools.HallOfFame(5)

# Estadísticas
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("avg", np.mean)
stats.register("min", np.min)

# Algoritmo genético sin elitismo
random.seed(42)
population_no_elitism = toolbox.population(n=300)

# Función para imprimir la información de cada generación
def print_generation_info(generation, population):
    best_ind = tools.selBest(population, 1)[0]
    print(f"**GENERATION**: {generation}")
    print("******************")
    if generation == 0:
        print("INITIAL RANDOM PATH AND DISTANCE:")
    else:
        print("PATH AND DISTANCE:")
    route = indices_to_cities(best_ind)
    print(" ==> ".join(route) + " ==> " + route[0])
    print(f"Fitness value: {best_ind.fitness.values[0]}")
    print("******************")

# Inicializa listas para almacenar datos de fitness
min_fitness_values = []
avg_fitness_values = []
generations = range(200)

# Ejecución del algoritmo genético con impresiones personalizadas
for gen in range(200):
    # Genera una nueva generación
    offspring = algorithms.varAnd(population_no_elitism, toolbox, cxpb=0.90, mutpb=0.1)

    # Evalúa a los individuos con un fitness inválido
    invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
    fitnesses = map(toolbox.evaluate, invalid_ind)
    for ind, fit in zip(invalid_ind, fitnesses):
        ind.fitness.values = fit

    # Actualiza la población
    population_no_elitism = toolbox.select(offspring, len(population_no_elitism))

    # Actualiza el Hall of Fame
    hof_no_elitism.update(population_no_elitism)

    # Imprime la información de la generación
    print_generation_info(gen, population_no_elitism)

    # Recolecta estadísticas
    record = stats.compile(population_no_elitism)
    print(record)

    # Recolecta y almacena los datos de fitness
    record = stats.compile(population_no_elitism)
    min_fitness_values.append(record['min'])
    avg_fitness_values.append(record['avg'])
# Out:
# **GENERATION**: 0
# ******************
# INITIAL RANDOM PATH AND DISTANCE:
# Seattle ==> Portland ==> Missoula ==> Twin Falls ==> Boise ==> Biggs ==> Bend ==> Grant Pass ==> Eugene ==> Lakeview ==> Burns ==> Spokane ==> Pendleton ==> Everett ==> Seattle
# Fitness value: 4233.192286079306
# ******************
# {'avg': 5701.494186193561, 'min': 4233.192286079306}
# **GENERATION**: 1
# ******************
# PATH AND DISTANCE:
# Everett ==> Seattle ==> Pendleton ==> Burns ==> Bend ==> Grant Pass ==> Twin Falls ==> Boise ==> Lakeview ==> Eugene ==> Portland ==> Biggs ==> Missoula ==> Spokane ==> Everett
# Fitness value: 4132.438923136287
# ******************
# {'avg': 5506.4858026644915, 'min': 4132.438923136287}
# **GENERATION**: 2
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Bend ==> Burns ==> Grant Pass ==> Twin Falls ==> Boise ==> Lakeview ==> Eugene ==> Portland ==> Biggs ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Pendleton
# Fitness value: 4296.302524670289
# ******************
# {'avg': 5408.098964417428, 'min': 4296.302524670289}
# **GENERATION**: 3
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Grant Pass ==> Eugene ==> Portland ==> Everett ==> Seattle ==> Burns ==> Bend ==> Lakeview ==> Biggs ==> Twin Falls ==> Boise ==> Missoula ==> Spokane ==> Pendleton
# Fitness value: 4206.070936715018
# ******************
# {'avg': 5301.4811626977325, 'min': 4206.070936715018}
# **GENERATION**: 4
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Bend ==> Burns ==> Grant Pass ==> Twin Falls ==> Boise ==> Lakeview ==> Eugene ==> Portland ==> Biggs ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Pendleton
# Fitness value: 4296.302524670289
# ******************
# {'avg': 5255.190711838968, 'min': 4296.302524670289}
# **GENERATION**: 5
# ******************
# PATH AND DISTANCE:
# Spokane ==> Missoula ==> Twin Falls ==> Burns ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Biggs ==> Seattle ==> Everett ==> Pendleton ==> Boise ==> Spokane
# Fitness value: 4073.222127807861
# ******************
# {'avg': 5135.927437089651, 'min': 4073.222127807861}
# **GENERATION**: 6
# ******************
# PATH AND DISTANCE:
# Lakeview ==> Grant Pass ==> Portland ==> Everett ==> Seattle ==> Pendleton ==> Bend ==> Eugene ==> Biggs ==> Missoula ==> Spokane ==> Twin Falls ==> Boise ==> Burns ==> Lakeview
# Fitness value: 3951.3055622019556
# ******************
# {'avg': 5061.914706641685, 'min': 3951.3055622019556}
# **GENERATION**: 7
# ******************
# PATH AND DISTANCE:
# Biggs ==> Burns ==> Bend ==> Grant Pass ==> Twin Falls ==> Boise ==> Lakeview ==> Eugene ==> Portland ==> Seattle ==> Everett ==> Missoula ==> Spokane ==> Pendleton ==> Biggs
# Fitness value: 4044.609816804579
# ******************
# {'avg': 5043.904967671887, 'min': 4044.609816804579}
# **GENERATION**: 8
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Lakeview ==> Grant Pass ==> Bend ==> Biggs ==> Pendleton ==> Eugene ==> Portland ==> Everett ==> Seattle ==> Spokane ==> Missoula ==> Boise ==> Burns ==> Twin Falls
# Fitness value: 3852.916329071706
# ******************
# {'avg': 5040.199103200516, 'min': 3852.916329071706}
# **GENERATION**: 9
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Bend ==> Eugene ==> Portland ==> Lakeview ==> Grant Pass ==> Burns ==> Biggs ==> Everett ==> Seattle ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Pendleton
# Fitness value: 3813.2201908959723
# ******************
# {'avg': 5004.710742939245, 'min': 3813.2201908959723}
# **GENERATION**: 10
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Boise ==> Burns ==> Eugene ==> Bend ==> Grant Pass ==> Lakeview ==> Pendleton ==> Spokane ==> Missoula ==> Everett ==> Seattle ==> Portland ==> Biggs ==> Twin Falls
# Fitness value: 3967.1736725447267
# ******************
# {'avg': 5009.422772104094, 'min': 3967.1736725447267}
# **GENERATION**: 11
# ******************
# PATH AND DISTANCE:
# Burns ==> Lakeview ==> Grant Pass ==> Biggs ==> Spokane ==> Pendleton ==> Bend ==> Eugene ==> Portland ==> Seattle ==> Everett ==> Missoula ==> Twin Falls ==> Boise ==> Burns
# Fitness value: 3809.196851329254
# ******************
# {'avg': 4945.601808607333, 'min': 3809.196851329254}
# **GENERATION**: 12
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Lakeview ==> Pendleton ==> Spokane ==> Missoula ==> Biggs ==> Twin Falls ==> Boise ==> Burns ==> Bend ==> Seattle ==> Everett ==> Portland ==> Eugene ==> Grant Pass
# Fitness value: 3999.1993348856577
# ******************
# {'avg': 4930.560987541142, 'min': 3999.1993348856577}
# **GENERATION**: 13
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Lakeview ==> Pendleton ==> Spokane ==> Missoula ==> Biggs ==> Twin Falls ==> Boise ==> Burns ==> Bend ==> Seattle ==> Everett ==> Portland ==> Eugene ==> Grant Pass
# Fitness value: 3999.1993348856577
# ******************
# {'avg': 4934.8347916809125, 'min': 3999.1993348856577}
# **GENERATION**: 14
# ******************
# PATH AND DISTANCE:
# Lakeview ==> Grant Pass ==> Eugene ==> Portland ==> Everett ==> Seattle ==> Spokane ==> Missoula ==> Boise ==> Twin Falls ==> Burns ==> Pendleton ==> Bend ==> Biggs ==> Lakeview
# Fitness value: 3601.2713192512124
# ******************
# {'avg': 4820.06271208057, 'min': 3601.2713192512124}
# **GENERATION**: 15
# ******************
# PATH AND DISTANCE:
# Lakeview ==> Grant Pass ==> Eugene ==> Portland ==> Everett ==> Seattle ==> Spokane ==> Missoula ==> Boise ==> Twin Falls ==> Burns ==> Pendleton ==> Bend ==> Biggs ==> Lakeview
# Fitness value: 3601.2713192512124
# ******************
# {'avg': 4778.222631266594, 'min': 3601.2713192512124}
# **GENERATION**: 16
# ******************
# PATH AND DISTANCE:
# Lakeview ==> Grant Pass ==> Eugene ==> Portland ==> Everett ==> Seattle ==> Spokane ==> Missoula ==> Boise ==> Twin Falls ==> Burns ==> Pendleton ==> Bend ==> Biggs ==> Lakeview
# Fitness value: 3601.2713192512124
# ******************
# {'avg': 4767.159501348861, 'min': 3601.2713192512124}
# **GENERATION**: 17
# ******************
# PATH AND DISTANCE:
# Biggs ==> Everett ==> Seattle ==> Spokane ==> Missoula ==> Pendleton ==> Burns ==> Twin Falls ==> Boise ==> Lakeview ==> Grant Pass ==> Bend ==> Portland ==> Eugene ==> Biggs
# Fitness value: 3640.1940583347773
# ******************
# {'avg': 4764.136065010132, 'min': 3640.1940583347773}
# **GENERATION**: 18
# ******************
# PATH AND DISTANCE:
# Seattle ==> Everett ==> Biggs ==> Pendleton ==> Burns ==> Lakeview ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Bend ==> Grant Pass ==> Eugene ==> Portland ==> Seattle
# Fitness value: 3531.6210478041266
# ******************
# {'avg': 4746.361170339415, 'min': 3531.6210478041266}
# **GENERATION**: 19
# ******************
# PATH AND DISTANCE:
# Bend ==> Seattle ==> Everett ==> Portland ==> Biggs ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Pendleton ==> Burns ==> Eugene ==> Grant Pass ==> Lakeview ==> Bend
# Fitness value: 3660.0774964384727
# ******************
# {'avg': 4699.88205239659, 'min': 3660.0774964384727}
# **GENERATION**: 20
# ******************
# PATH AND DISTANCE:
# Bend ==> Seattle ==> Everett ==> Portland ==> Biggs ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Pendleton ==> Burns ==> Eugene ==> Grant Pass ==> Lakeview ==> Bend
# Fitness value: 3660.0774964384727
# ******************
# {'avg': 4654.72849026055, 'min': 3660.0774964384727}
# **GENERATION**: 21
# ******************
# PATH AND DISTANCE:
# Everett ==> Seattle ==> Biggs ==> Pendleton ==> Burns ==> Lakeview ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Bend ==> Eugene ==> Grant Pass ==> Portland ==> Everett
# Fitness value: 3619.504034017657
# ******************
# {'avg': 4631.071359278091, 'min': 3619.504034017657}
# **GENERATION**: 22
# ******************
# PATH AND DISTANCE:
# Lakeview ==> Burns ==> Pendleton ==> Bend ==> Twin Falls ==> Boise ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Biggs ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview
# Fitness value: 3552.43990510465
# ******************
# {'avg': 4584.067065381665, 'min': 3552.43990510465}
# **GENERATION**: 23
# ******************
# PATH AND DISTANCE:
# Seattle ==> Portland ==> Pendleton ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Biggs ==> Grant Pass ==> Lakeview ==> Bend ==> Eugene ==> Everett ==> Seattle
# Fitness value: 3725.330172238472
# ******************
# {'avg': 4558.063207349926, 'min': 3725.330172238472}
# **GENERATION**: 24
# ******************
# PATH AND DISTANCE:
# Everett ==> Seattle ==> Burns ==> Lakeview ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Eugene ==> Grant Pass ==> Bend ==> Portland ==> Everett
# Fitness value: 3603.544758451092
# ******************
# {'avg': 4527.213826046846, 'min': 3603.544758451092}
# **GENERATION**: 25
# ******************
# PATH AND DISTANCE:
# Missoula ==> Twin Falls ==> Boise ==> Burns ==> Pendleton ==> Lakeview ==> Grant Pass ==> Portland ==> Biggs ==> Bend ==> Eugene ==> Everett ==> Seattle ==> Spokane ==> Missoula
# Fitness value: 3722.2084693090933
# ******************
# {'avg': 4530.75312393315, 'min': 3722.2084693090933}
# **GENERATION**: 26
# ******************
# PATH AND DISTANCE:
# Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Bend ==> Grant Pass ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Eugene ==> Lakeview
# Fitness value: 3543.3841436200855
# ******************
# {'avg': 4551.563921028423, 'min': 3543.3841436200855}
# **GENERATION**: 27
# ******************
# PATH AND DISTANCE:
# Biggs ==> Seattle ==> Everett ==> Spokane ==> Missoula ==> Boise ==> Twin Falls ==> Burns ==> Pendleton ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Portland ==> Biggs
# Fitness value: 3524.8564650273274
# ******************
# {'avg': 4566.432872134942, 'min': 3524.8564650273274}
# **GENERATION**: 28
# ******************
# PATH AND DISTANCE:
# Biggs ==> Seattle ==> Everett ==> Spokane ==> Missoula ==> Boise ==> Twin Falls ==> Burns ==> Pendleton ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Portland ==> Biggs
# Fitness value: 3524.8564650273274
# ******************
# {'avg': 4561.995606778658, 'min': 3524.8564650273274}
# **GENERATION**: 29
# ******************
# PATH AND DISTANCE:
# Seattle ==> Everett ==> Spokane ==> Missoula ==> Boise ==> Twin Falls ==> Burns ==> Pendleton ==> Biggs ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Portland ==> Seattle
# Fitness value: 3443.5522499985254
# ******************
# {'avg': 4560.626667849707, 'min': 3443.5522499985254}
# **GENERATION**: 30
# ******************
# PATH AND DISTANCE:
# Seattle ==> Everett ==> Spokane ==> Missoula ==> Boise ==> Twin Falls ==> Burns ==> Pendleton ==> Biggs ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Portland ==> Seattle
# Fitness value: 3443.5522499985254
# ******************
# {'avg': 4553.7192174523325, 'min': 3443.5522499985254}
# **GENERATION**: 31
# ******************
# PATH AND DISTANCE:
# Seattle ==> Everett ==> Spokane ==> Missoula ==> Boise ==> Twin Falls ==> Burns ==> Bend ==> Grant Pass ==> Lakeview ==> Eugene ==> Biggs ==> Portland ==> Pendleton ==> Seattle
# Fitness value: 3683.3536024340983
# ******************
# {'avg': 4590.226201801657, 'min': 3683.3536024340983}
# **GENERATION**: 32
# ******************
# PATH AND DISTANCE:
# Portland ==> Biggs ==> Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Portland
# Fitness value: 3467.8222176661616
# ******************
# {'avg': 4529.769120152333, 'min': 3467.8222176661616}
# **GENERATION**: 33
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Biggs ==> Everett ==> Seattle ==> Bend ==> Portland ==> Grant Pass ==> Eugene ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton
# Fitness value: 3502.881837688484
# ******************
# {'avg': 4495.418573838669, 'min': 3502.881837688484}
# **GENERATION**: 34
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Biggs ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Portland ==> Grant Pass ==> Eugene ==> Lakeview ==> Burns ==> Bend ==> Pendleton
# Fitness value: 3688.7789971173343
# ******************
# {'avg': 4489.850484254483, 'min': 3688.7789971173343}
# **GENERATION**: 35
# ******************
# PATH AND DISTANCE:
# Portland ==> Biggs ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Pendleton ==> Bend ==> Eugene ==> Portland
# Fitness value: 3510.9310499140447
# ******************
# {'avg': 4494.852533274642, 'min': 3510.9310499140447}
# **GENERATION**: 36
# ******************
# PATH AND DISTANCE:
# Portland ==> Biggs ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Pendleton ==> Bend ==> Eugene ==> Portland
# Fitness value: 3510.9310499140447
# ******************
# {'avg': 4464.438276788554, 'min': 3510.9310499140447}
# **GENERATION**: 37
# ******************
# PATH AND DISTANCE:
# Portland ==> Biggs ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Pendleton ==> Bend ==> Eugene ==> Portland
# Fitness value: 3510.9310499140447
# ******************
# {'avg': 4441.233598416812, 'min': 3510.9310499140447}
# **GENERATION**: 38
# ******************
# PATH AND DISTANCE:
# Biggs ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Pendleton ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Bend ==> Biggs
# Fitness value: 3516.456292946519
# ******************
# {'avg': 4450.280176395493, 'min': 3516.456292946519}
# **GENERATION**: 39
# ******************
# PATH AND DISTANCE:
# Burns ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Portland ==> Seattle ==> Everett ==> Biggs ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Boise ==> Burns
# Fitness value: 3600.2497709568897
# ******************
# {'avg': 4487.655452596542, 'min': 3600.2497709568897}
# **GENERATION**: 40
# ******************
# PATH AND DISTANCE:
# Seattle ==> Everett ==> Biggs ==> Pendleton ==> Portland ==> Eugene ==> Lakeview ==> Grant Pass ==> Bend ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle
# Fitness value: 3468.249301940674
# ******************
# {'avg': 4473.738124883673, 'min': 3468.249301940674}
# **GENERATION**: 41
# ******************
# PATH AND DISTANCE:
# Bend ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Biggs ==> Pendleton ==> Bend
# Fitness value: 3516.5695413290464
# ******************
# {'avg': 4517.435356286529, 'min': 3516.5695413290464}
# **GENERATION**: 42
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Bend ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Portland ==> Everett ==> Seattle ==> Eugene ==> Lakeview ==> Grant Pass
# Fitness value: 3415.898929130481
# ******************
# {'avg': 4480.608767795797, 'min': 3415.898929130481}
# **GENERATION**: 43
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Everett ==> Seattle ==> Biggs ==> Burns ==> Bend ==> Eugene ==> Portland ==> Grant Pass ==> Lakeview ==> Twin Falls ==> Boise ==> Missoula ==> Spokane ==> Pendleton
# Fitness value: 3602.7921149666
# ******************
# {'avg': 4443.895985781826, 'min': 3602.7921149666}
# **GENERATION**: 44
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Everett ==> Seattle ==> Biggs ==> Burns ==> Bend ==> Eugene ==> Portland ==> Grant Pass ==> Lakeview ==> Twin Falls ==> Boise ==> Missoula ==> Spokane ==> Pendleton
# Fitness value: 3602.7921149666
# ******************
# {'avg': 4436.61342755653, 'min': 3602.7921149666}
# **GENERATION**: 45
# ******************
# PATH AND DISTANCE:
# Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Portland ==> Seattle ==> Everett ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula
# Fitness value: 3187.860126527307
# ******************
# {'avg': 4434.137158593004, 'min': 3187.860126527307}
# **GENERATION**: 46
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Everett ==> Seattle ==> Biggs ==> Burns ==> Bend ==> Eugene ==> Portland ==> Grant Pass ==> Lakeview ==> Twin Falls ==> Boise ==> Missoula ==> Spokane ==> Pendleton
# Fitness value: 3602.7921149666
# ******************
# {'avg': 4412.729131580404, 'min': 3602.7921149666}
# **GENERATION**: 47
# ******************
# PATH AND DISTANCE:
# Biggs ==> Portland ==> Bend ==> Grant Pass ==> Lakeview ==> Eugene ==> Burns ==> Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Biggs
# Fitness value: 3627.3691900076774
# ******************
# {'avg': 4422.412098279019, 'min': 3627.3691900076774}
# **GENERATION**: 48
# ******************
# PATH AND DISTANCE:
# Biggs ==> Pendleton ==> Grant Pass ==> Portland ==> Eugene ==> Bend ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Biggs
# Fitness value: 3547.6991571465846
# ******************
# {'avg': 4418.484690678734, 'min': 3547.6991571465846}
# **GENERATION**: 49
# ******************
# PATH AND DISTANCE:
# Biggs ==> Pendleton ==> Grant Pass ==> Portland ==> Eugene ==> Bend ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Biggs
# Fitness value: 3547.6991571465846
# ******************
# {'avg': 4465.745110398048, 'min': 3547.6991571465846}
# **GENERATION**: 50
# ******************
# PATH AND DISTANCE:
# Seattle ==> Biggs ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Boise ==> Twin Falls ==> Burns ==> Pendleton ==> Spokane ==> Missoula ==> Everett ==> Seattle
# Fitness value: 3524.967115999336
# ******************
# {'avg': 4508.37462025555, 'min': 3524.967115999336}
# **GENERATION**: 51
# ******************
# PATH AND DISTANCE:
# Seattle ==> Biggs ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Boise ==> Twin Falls ==> Burns ==> Pendleton ==> Spokane ==> Missoula ==> Everett ==> Seattle
# Fitness value: 3524.967115999336
# ******************
# {'avg': 4555.2147421927275, 'min': 3524.967115999336}
# **GENERATION**: 52
# ******************
# PATH AND DISTANCE:
# Eugene ==> Bend ==> Pendleton ==> Burns ==> Grant Pass ==> Lakeview ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Biggs ==> Seattle ==> Everett ==> Portland ==> Eugene
# Fitness value: 3642.208624904302
# ******************
# {'avg': 4632.95971033736, 'min': 3642.208624904302}
# **GENERATION**: 53
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Biggs ==> Boise ==> Pendleton
# Fitness value: 3826.4081813109624
# ******************
# {'avg': 4741.72239062837, 'min': 3826.4081813109624}
# **GENERATION**: 54
# ******************
# PATH AND DISTANCE:
# Eugene ==> Grant Pass ==> Biggs ==> Pendleton ==> Bend ==> Lakeview ==> Burns ==> Twin Falls ==> Boise ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Portland ==> Eugene
# Fitness value: 3528.4510981089325
# ******************
# {'avg': 4684.472569785154, 'min': 3528.4510981089325}
# **GENERATION**: 55
# ******************
# PATH AND DISTANCE:
# Biggs ==> Boise ==> Burns ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Twin Falls ==> Missoula ==> Spokane ==> Everett ==> Seattle ==> Portland ==> Pendleton ==> Biggs
# Fitness value: 3759.490420283762
# ******************
# {'avg': 4626.608525826934, 'min': 3759.490420283762}
# **GENERATION**: 56
# ******************
# PATH AND DISTANCE:
# Bend ==> Grant Pass ==> Eugene ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend
# Fitness value: 3231.2229162091835
# ******************
# {'avg': 4636.436772575069, 'min': 3231.2229162091835}
# **GENERATION**: 57
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Lakeview ==> Eugene ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend ==> Grant Pass
# Fitness value: 3441.1705746509856
# ******************
# {'avg': 4630.5491280510505, 'min': 3441.1705746509856}
# **GENERATION**: 58
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Lakeview ==> Eugene ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend ==> Grant Pass
# Fitness value: 3441.1705746509856
# ******************
# {'avg': 4559.549941868627, 'min': 3441.1705746509856}
# **GENERATION**: 59
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Lakeview ==> Eugene ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend ==> Grant Pass
# Fitness value: 3441.1705746509856
# ******************
# {'avg': 4574.20703361738, 'min': 3441.1705746509856}
# **GENERATION**: 60
# ******************
# PATH AND DISTANCE:
# Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett ==> Seattle ==> Portland ==> Biggs ==> Bend ==> Eugene
# Fitness value: 3136.3353561134936
# ******************
# {'avg': 4516.623044977894, 'min': 3136.3353561134936}
# **GENERATION**: 61
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Lakeview ==> Eugene ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend ==> Grant Pass
# Fitness value: 3441.1705746509856
# ******************
# {'avg': 4486.10909861503, 'min': 3441.1705746509856}
# **GENERATION**: 62
# ******************
# PATH AND DISTANCE:
# Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend ==> Eugene
# Fitness value: 3074.099060637657
# ******************
# {'avg': 4459.953649049221, 'min': 3074.099060637657}
# **GENERATION**: 63
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Eugene ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett ==> Seattle ==> Portland ==> Biggs ==> Bend ==> Grant Pass
# Fitness value: 3293.45921168502
# ******************
# {'avg': 4403.875015356787, 'min': 3293.45921168502}
# **GENERATION**: 64
# ******************
# PATH AND DISTANCE:
# Biggs ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett ==> Seattle ==> Portland ==> Eugene ==> Bend ==> Biggs
# Fitness value: 3389.6026059481906
# ******************
# {'avg': 4391.542166400424, 'min': 3389.6026059481906}
# **GENERATION**: 65
# ******************
# PATH AND DISTANCE:
# Biggs ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett ==> Seattle ==> Portland ==> Eugene ==> Bend ==> Biggs
# Fitness value: 3389.6026059481906
# ******************
# {'avg': 4395.989333852407, 'min': 3389.6026059481906}
# **GENERATION**: 66
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Biggs ==> Bend ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Pendleton
# Fitness value: 3322.858581330191
# ******************
# {'avg': 4368.556550638631, 'min': 3322.858581330191}
# **GENERATION**: 67
# ******************
# PATH AND DISTANCE:
# Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett ==> Seattle ==> Portland ==> Bend ==> Biggs ==> Eugene
# Fitness value: 3297.583138000305
# ******************
# {'avg': 4304.553939931697, 'min': 3297.583138000305}
# **GENERATION**: 68
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Missoula ==> Spokane ==> Seattle ==> Everett ==> Pendleton ==> Biggs ==> Bend ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls
# Fitness value: 3261.3307278389857
# ******************
# {'avg': 4261.404432163767, 'min': 3261.3307278389857}
# **GENERATION**: 69
# ******************
# PATH AND DISTANCE:
# Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Portland ==> Seattle ==> Everett ==> Eugene ==> Bend ==> Grant Pass ==> Lakeview
# Fitness value: 3252.3941911671263
# ******************
# {'avg': 4163.619506295768, 'min': 3252.3941911671263}
# **GENERATION**: 70
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett ==> Seattle ==> Portland ==> Bend ==> Biggs ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls
# Fitness value: 3297.583138000305
# ******************
# {'avg': 4160.025327447736, 'min': 3297.583138000305}
# **GENERATION**: 71
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Missoula ==> Spokane ==> Biggs ==> Pendleton ==> Seattle ==> Everett ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls
# Fitness value: 3283.1707021922825
# ******************
# {'avg': 4094.263045854248, 'min': 3283.1707021922825}
# **GENERATION**: 72
# ******************
# PATH AND DISTANCE:
# Twin Falls ==> Missoula ==> Spokane ==> Biggs ==> Pendleton ==> Seattle ==> Everett ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls
# Fitness value: 3283.1707021922825
# ******************
# {'avg': 4084.4569951232866, 'min': 3283.1707021922825}
# **GENERATION**: 73
# ******************
# PATH AND DISTANCE:
# Missoula ==> Spokane ==> Pendleton ==> Seattle ==> Everett ==> Biggs ==> Bend ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula
# Fitness value: 3234.892615519056
# ******************
# {'avg': 4121.706009853985, 'min': 3234.892615519056}
# **GENERATION**: 74
# ******************
# PATH AND DISTANCE:
# Missoula ==> Spokane ==> Pendleton ==> Seattle ==> Everett ==> Portland ==> Biggs ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula
# Fitness value: 3159.1133705564175
# ******************
# {'avg': 4039.1493846869143, 'min': 3159.1133705564175}
# **GENERATION**: 75
# ******************
# PATH AND DISTANCE:
# Missoula ==> Spokane ==> Pendleton ==> Seattle ==> Everett ==> Portland ==> Biggs ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula
# Fitness value: 3159.1133705564175
# ******************
# {'avg': 3958.9221810495296, 'min': 3159.1133705564175}
# **GENERATION**: 76
# ******************
# PATH AND DISTANCE:
# Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3912.1364205655905, 'min': 3074.099060637657}
# **GENERATION**: 77
# ******************
# PATH AND DISTANCE:
# Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3952.1184848761714, 'min': 3074.099060637657}
# **GENERATION**: 78
# ******************
# PATH AND DISTANCE:
# Everett ==> Seattle ==> Biggs ==> Portland ==> Eugene ==> Grant Pass ==> Bend ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett
# Fitness value: 3205.223136064148
# ******************
# {'avg': 3948.179046737714, 'min': 3205.223136064148}
# **GENERATION**: 79
# ******************
# PATH AND DISTANCE:
# Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Bend ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula
# Fitness value: 3267.0668937292307
# ******************
# {'avg': 3906.1002112819388, 'min': 3267.0668937292307}
# **GENERATION**: 80
# ******************
# PATH AND DISTANCE:
# Biggs ==> Everett ==> Seattle ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3938.1379190445923, 'min': 3074.099060637657}
# **GENERATION**: 81
# ******************
# PATH AND DISTANCE:
# Bend ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Everett ==> Seattle ==> Biggs ==> Bend
# Fitness value: 3221.3064989019335
# ******************
# {'avg': 3923.989921521857, 'min': 3221.3064989019335}
# **GENERATION**: 82
# ******************
# PATH AND DISTANCE:
# Biggs ==> Everett ==> Seattle ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3855.053009280837, 'min': 3074.099060637657}
# **GENERATION**: 83
# ******************
# PATH AND DISTANCE:
# Biggs ==> Seattle ==> Everett ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs
# Fitness value: 3083.29095846346
# ******************
# {'avg': 3841.9484881931126, 'min': 3083.29095846346}
# **GENERATION**: 84
# ******************
# PATH AND DISTANCE:
# Biggs ==> Seattle ==> Everett ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs
# Fitness value: 3083.29095846346
# ******************
# {'avg': 3828.6961679756178, 'min': 3083.29095846346}
# **GENERATION**: 85
# ******************
# PATH AND DISTANCE:
# Seattle ==> Everett ==> Portland ==> Eugene ==> Grant Pass ==> Bend ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Seattle
# Fitness value: 3129.7685009615175
# ******************
# {'avg': 3810.656814344359, 'min': 3129.7685009615175}
# **GENERATION**: 86
# ******************
# PATH AND DISTANCE:
# Seattle ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Bend ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle
# Fitness value: 3127.101108861305
# ******************
# {'avg': 3759.7260795254215, 'min': 3127.101108861305}
# **GENERATION**: 87
# ******************
# PATH AND DISTANCE:
# Seattle ==> Portland ==> Eugene ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle
# Fitness value: 3109.555894508543
# ******************
# {'avg': 3712.635130975222, 'min': 3109.555894508543}
# **GENERATION**: 88
# ******************
# PATH AND DISTANCE:
# Seattle ==> Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3659.8139944716613, 'min': 3074.099060637657}
# **GENERATION**: 89
# ******************
# PATH AND DISTANCE:
# Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Seattle ==> Everett ==> Portland
# Fitness value: 3083.29095846346
# ******************
# {'avg': 3737.9958841334005, 'min': 3083.29095846346}
# **GENERATION**: 90
# ******************
# PATH AND DISTANCE:
# Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3692.302724205972, 'min': 3074.099060637657}
# **GENERATION**: 91
# ******************
# PATH AND DISTANCE:
# Everett ==> Portland ==> Eugene ==> Grant Pass ==> Lakeview ==> Bend ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Seattle ==> Everett
# Fitness value: 3136.2930066871077
# ******************
# {'avg': 3650.6034227033315, 'min': 3136.2930066871077}
# **GENERATION**: 92
# ******************
# PATH AND DISTANCE:
# Portland ==> Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3599.8443895984146, 'min': 3074.099060637657}
# **GENERATION**: 93
# ******************
# PATH AND DISTANCE:
# Eugene ==> Bend ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Seattle ==> Everett ==> Portland ==> Eugene
# Fitness value: 3118.747792334346
# ******************
# {'avg': 3612.285139280291, 'min': 3118.747792334346}
# **GENERATION**: 94
# ******************
# PATH AND DISTANCE:
# Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3581.3721078540198, 'min': 3074.099060637657}
# **GENERATION**: 95
# ******************
# PATH AND DISTANCE:
# Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3598.6486970546966, 'min': 3074.099060637657}
# **GENERATION**: 96
# ******************
# PATH AND DISTANCE:
# Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Seattle ==> Everett ==> Portland ==> Bend
# Fitness value: 3083.29095846346
# ******************
# {'avg': 3562.998283590142, 'min': 3083.29095846346}
# **GENERATION**: 97
# ******************
# PATH AND DISTANCE:
# Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Seattle ==> Everett ==> Portland ==> Bend ==> Eugene
# Fitness value: 3083.29095846346
# ******************
# {'avg': 3536.371579413122, 'min': 3083.29095846346}
# **GENERATION**: 98
# ******************
# PATH AND DISTANCE:
# Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend ==> Eugene
# Fitness value: 3074.099060637657
# ******************
# {'avg': 
# ******************
# PATH AND DISTANCE:
# Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3074.0990606376577, 'min': 3074.099060637657}
# **GENERATION**: 192
# ******************
# PATH AND DISTANCE:
# Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3074.0990606376577, 'min': 3074.099060637657}
# **GENERATION**: 193
# ******************
# PATH AND DISTANCE:
# Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3075.1284593887967, 'min': 3074.099060637657}
# **GENERATION**: 194
# ******************
# PATH AND DISTANCE:
# Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3080.8215703378014, 'min': 3074.099060637657}
# **GENERATION**: 195
# ******************
# PATH AND DISTANCE:
# Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3083.7248613237102, 'min': 3074.099060637657}
# **GENERATION**: 196
# ******************
# PATH AND DISTANCE:
# Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3081.178705907599, 'min': 3074.099060637657}
# **GENERATION**: 197
# ******************
# PATH AND DISTANCE:
# Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3081.728379629051, 'min': 3074.099060637657}
# **GENERATION**: 198
# ******************
# PATH AND DISTANCE:
# Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3080.04619945447, 'min': 3074.099060637657}
# **GENERATION**: 199
# ******************
# PATH AND DISTANCE:
# Bend ==> Eugene ==> Grant Pass ==> Lakeview ==> Burns ==> Boise ==> Twin Falls ==> Missoula ==> Spokane ==> Pendleton ==> Biggs ==> Everett ==> Seattle ==> Portland ==> Bend
# Fitness value: 3074.099060637657
# ******************
# {'avg': 3076.9063214293333, 'min': 3074.099060637657}

# %%
# Hall of Fame para la versión con elitismo
hof_elitism = tools.HallOfFame(30)

# Estadísticas
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("avg", np.mean)
stats.register("min", np.min)

# Función para imprimir la información de cada generación
def print_generation_info(generation, population):
    best_ind = tools.selBest(population, 1)[0]
    print(f"**GENERATION**: {generation}")
    print("******************")
    if generation == 0:
        print("INITIAL RANDOM PATH AND DISTANCE:")
    else:
        print("PATH AND DISTANCE:")
    route = indices_to_cities(best_ind)
    print(" ==> ".join(route) + " ==> " + route[0])
    print(f"Fitness value: {best_ind.fitness.values[0]}")
    print("******************")

# Algoritmo genético con elitismo
random.seed(42)
population_elitism = toolbox.population(n=300)

# Número de individuos a mantener en cada generación (elitismo)
num_elites = 30

# Inicializa listas para almacenar datos de fitness
min_fitness_values2 = []
avg_fitness_values2 = []
generations2 = range(200)

for gen in range(200):
    # Genera una nueva generación
    offspring = algorithms.varAnd(population_elitism, toolbox, cxpb=0.90, mutpb=0.1)

    # Evalúa a los individuos con un fitness inválido
    invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
    fitnesses = map(toolbox.evaluate, invalid_ind)
    for ind, fit in zip(invalid_ind, fitnesses):
        ind.fitness.values = fit

    # Elitismo: Selecciona los mejores individuos y los agrega a la nueva generación
    elites = tools.selBest(population_elitism, num_elites)
    offspring = toolbox.select(offspring, len(population_elitism) - num_elites)

    # Asegúrate de que todos los elites tienen un valor de fitness asignado
    for elite in elites:
        if not elite.fitness.valid:
            elite.fitness.values = toolbox.evaluate(elite)

    # Combina los elites con el resto de la descendencia
    offspring.extend(elites)

    # Actualiza la población
    population_elitism = offspring

    # Actualiza el Hall of Fame
    hof_elitism.update(population_elitism)

    # Imprime la información de la generación
    print_generation_info(gen, population_elitism)

    # Verifica y recolecta estadísticas
    for ind in population_elitism:
        if not ind.fitness.valid:
            ind.fitness.values = toolbox.evaluate(ind)

    record = stats.compile(population_elitism)
    print(record)

    # Recolecta y almacena los datos de fitness
    record = stats.compile(population_elitism)
    min_fitness_values2.append(record['min'])
    avg_fitness_values2.append(record['avg'])
# Out:
# **GENERATION**: 0
# ******************
# INITIAL RANDOM PATH AND DISTANCE:
# Seattle ==> Portland ==> Missoula ==> Twin Falls ==> Boise ==> Biggs ==> Bend ==> Grant Pass ==> Eugene ==> Lakeview ==> Burns ==> Spokane ==> Pendleton ==> Everett ==> Seattle
# Fitness value: 4233.192286079306
# ******************
# {'avg': 5720.1970585584395, 'min': 4233.192286079306}
# **GENERATION**: 1
# ******************
# PATH AND DISTANCE:
# Everett ==> Seattle ==> Pendleton ==> Burns ==> Bend ==> Grant Pass ==> Twin Falls ==> Boise ==> Lakeview ==> Eugene ==> Portland ==> Biggs ==> Missoula ==> Spokane ==> Everett
# Fitness value: 4132.438923136287
# ******************
# {'avg': 5414.872394866935, 'min': 4132.438923136287}
# **GENERATION**: 2
# ******************
# PATH AND DISTANCE:
# Everett ==> Seattle ==> Pendleton ==> Burns ==> Bend ==> Grant Pass ==> Twin Falls ==> Boise ==> Lakeview ==> Eugene ==> Portland ==> Biggs ==> Missoula ==> Spokane ==> Everett
# Fitness value: 4132.438923136287
# ******************
# {'avg': 5203.167080214517, 'min': 4132.438923136287}
# **GENERATION**: 3
# ******************
# PATH AND DISTANCE:
# Eugene ==> Grant Pass ==> Spokane ==> Missoula ==> Biggs ==> Pendleton ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Bend ==> Everett ==> Seattle ==> Portland ==> Eugene
# Fitness value: 4093.044516131971
# ******************
# {'avg': 5050.509750271425, 'min': 4093.044516131971}
# **GENERATION**: 4
# ******************
# PATH AND DISTANCE:
# Eugene ==> Grant Pass ==> Spokane ==> Missoula ==> Biggs ==> Pendleton ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Bend ==> Everett ==> Seattle ==> Portland ==> Eugene
# Fitness value: 4093.044516131971
# ******************
# {'avg': 4872.224505018432, 'min': 4093.044516131971}
# **GENERATION**: 5
# ******************
# PATH AND DISTANCE:
# Spokane ==> Seattle ==> Everett ==> Bend ==> Grant Pass ==> Lakeview ==> Eugene ==> Portland ==> Biggs ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Pendleton ==> Spokane
# Fitness value: 3871.284052874103
# ******************
# {'avg': 4649.362702916293, 'min': 3871.284052874103}
# **GENERATION**: 6
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Eugene ==> Portland ==> Biggs ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Bend ==> Pendleton ==> Seattle ==> Everett ==> Grant Pass
# Fitness value: 3686.0724962072672
# ******************
# {'avg': 4494.277137903964, 'min': 3686.0724962072672}
# **GENERATION**: 7
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Eugene ==> Portland ==> Biggs ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Bend ==> Pendleton ==> Seattle ==> Everett ==> Grant Pass
# Fitness value: 3686.0724962072672
# ******************
# {'avg': 4362.461090266498, 'min': 3686.0724962072672}
# **GENERATION**: 8
# ******************
# PATH AND DISTANCE:
# Eugene ==> Grant Pass ==> Pendleton ==> Biggs ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Bend ==> Everett ==> Seattle ==> Portland ==> Eugene
# Fitness value: 3650.294128844685
# ******************
# {'avg': 4317.32698773056, 'min': 3650.294128844685}
# **GENERATION**: 9
# ******************
# PATH AND DISTANCE:
# Biggs ==> Pendleton ==> Spokane ==> Missoula ==> Boise ==> Twin Falls ==> Burns ==> Lakeview ==> Bend ==> Everett ==> Seattle ==> Portland ==> Eugene ==> Grant Pass ==> Biggs
# Fitness value: 3534.102059659523
# ******************
# {'avg': 4197.352339151144, 'min': 3534.102059659523}
# **GENERATION**: 10
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Eugene ==> Biggs ==> Pendleton ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Bend ==> Everett ==> Seattle ==> Portland ==> Grant Pass
# Fitness value: 3474.2765392999036
# ******************
# {'avg': 4109.363481084231, 'min': 3474.2765392999036}
# **GENERATION**: 11
# ******************
# PATH AND DISTANCE:
# Pendleton ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Bend ==> Everett ==> Seattle ==> Portland ==> Eugene ==> Grant Pass ==> Biggs ==> Pendleton
# Fitness value: 3452.1480849891764
# ******************
# {'avg': 4075.7151273410377, 'min': 3452.1480849891764}
# **GENERATION**: 12
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Portland ==> Seattle ==> Everett ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Bend ==> Pendleton ==> Biggs ==> Eugene ==> Grant Pass
# Fitness value: 3418.07471710266
# ******************
# {'avg': 4081.4838873616404, 'min': 3418.07471710266}
# **GENERATION**: 13
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Portland ==> Seattle ==> Everett ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Pendleton ==> Biggs ==> Bend ==> Eugene ==> Grant Pass
# Fitness value: 3406.3139212286374
# ******************
# {'avg': 3998.7694830808027, 'min': 3406.3139212286374}
# **GENERATION**: 14
# ******************
# PATH AND DISTANCE:
# Grant Pass ==> Portland ==> Seattle ==> Everett ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Pendleton ==> Biggs ==> Bend ==> Eugene ==> Grant Pass
# Fitness value: 3406.3139212286374
# ******************
# {'avg': 3887.3020123701044, 'min': 3406.3139212286374}
# **GENERATION**: 15
# ******************
# PATH AND DISTANCE:
# Seattle ==> Everett ==> Biggs ==> Pendleton ==> Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Bend ==>
# ******************
# PATH AND DISTANCE:
# Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Grant Pass ==> Eugene ==> Bend ==> Portland ==> Seattle ==> Everett ==> Biggs ==> Pendleton ==> Spokane
# Fitness value: 3074.0990606376567
# ******************
# {'avg': 3078.6476488147046, 'min': 3074.0990606376567}
# **GENERATION**: 193
# ******************
# PATH AND DISTANCE:
# Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Grant Pass ==> Eugene ==> Bend ==> Portland ==> Seattle ==> Everett ==> Biggs ==> Pendleton ==> Spokane
# Fitness value: 3074.0990606376567
# ******************
# {'avg': 3074.099060637657, 'min': 3074.0990606376567}
# **GENERATION**: 194
# ******************
# PATH AND DISTANCE:
# Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Grant Pass ==> Eugene ==> Bend ==> Portland ==> Seattle ==> Everett ==> Biggs ==> Pendleton ==> Spokane
# Fitness value: 3074.0990606376567
# ******************
# {'avg': 3074.6228068228957, 'min': 3074.0990606376567}
# **GENERATION**: 195
# ******************
# PATH AND DISTANCE:
# Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Grant Pass ==> Eugene ==> Bend ==> Portland ==> Seattle ==> Everett ==> Biggs ==> Pendleton ==> Spokane
# Fitness value: 3074.0990606376567
# ******************
# {'avg': 3074.099060637657, 'min': 3074.0990606376567}
# **GENERATION**: 196
# ******************
# PATH AND DISTANCE:
# Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Grant Pass ==> Eugene ==> Bend ==> Portland ==> Seattle ==> Everett ==> Biggs ==> Pendleton ==> Spokane
# Fitness value: 3074.0990606376567
# ******************
# {'avg': 3074.099060637657, 'min': 3074.0990606376567}
# **GENERATION**: 197
# ******************
# PATH AND DISTANCE:
# Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Grant Pass ==> Eugene ==> Bend ==> Portland ==> Seattle ==> Everett ==> Biggs ==> Pendleton ==> Spokane
# Fitness value: 3074.0990606376567
# ******************
# {'avg': 3088.3717579790964, 'min': 3074.0990606376567}
# **GENERATION**: 198
# ******************
# PATH AND DISTANCE:
# Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Grant Pass ==> Eugene ==> Bend ==> Portland ==> Seattle ==> Everett ==> Biggs ==> Pendleton ==> Spokane
# Fitness value: 3074.0990606376567
# ******************
# {'avg': 3076.8152898966755, 'min': 3074.0990606376567}
# **GENERATION**: 199
# ******************
# PATH AND DISTANCE:
# Spokane ==> Missoula ==> Twin Falls ==> Boise ==> Burns ==> Lakeview ==> Grant Pass ==> Eugene ==> Bend ==> Portland ==> Seattle ==> Everett ==> Biggs ==> Pendleton ==> Spokane
# Fitness value: 3074.0990606376567
# ******************
# {'avg': 3078.55663332331, 'min': 3074.0990606376567}

# %% [markdown]
# # Visualización - Rutas

# %%
def plot_route(route, title):
    # Convierte la ruta a coordenadas proyectadas
    route_coords = [projected_cities[city] for city in route]
    route_coords.append(route_coords[0])  # Regresar a la ciudad inicial

    # Desempaqueta las coordenadas
    x, y = zip(*route_coords)

    # Configura el gráfico
    plt.figure(figsize=(10, 8))
    plt.plot(x, y, 'o-', mfc='r')
    plt.gca().invert_xaxis()  # Invertir el eje X
    plt.title(title)

    # Etiqueta cada ciudad en el gráfico
    for city, (xi, yi) in projected_cities.items():
        plt.text(xi, yi, city)

    plt.show()

# %% [markdown]
# ## Mejor Ruta de la Población y de Todas las Generaciones

# %%
# Visualizar la mejor ruta de la primera generación sin elitismo
best_route_first_generation_no_elitism = indices_to_cities(tools.selBest(population_no_elitism, 1)[0])
plot_route(best_route_first_generation_no_elitism, "Mejor Ruta Primera Generación Sin Elitismo")

# Visualizar la mejor ruta de todas las generaciones sin elitismo
best_route_all_generations_no_elitism = indices_to_cities(hof_no_elitism[0])
plot_route(best_route_all_generations_no_elitism, "Mejor Ruta de Todas las Generaciones Sin Elitismo")

# Visualizar la mejor ruta de la primera generación con elitismo
best_route_first_generation_elitism = indices_to_cities(tools.selBest(population_elitism, 1)[0])
plot_route(best_route_first_generation_elitism, "Mejor Ruta Primera Generación Con Elitismo")

# Visualizar la mejor ruta de todas las generaciones con elitismo
best_route_all_generations_elitism = indices_to_cities(hof_elitism[0])
plot_route(best_route_all_generations_elitism, "Mejor Ruta de Todas las Generaciones Con Elitismo")

# %% [markdown]
# # Visualizacion del Progreso del Fitness

# %%
def plot_fitness(generations, min_fitness, avg_fitness, title):
    plt.figure(figsize=(12, 8))
    plt.plot(generations, min_fitness, label="Fitness Mínimo")
    plt.plot(generations, avg_fitness, label="Fitness Promedio")
    plt.title(title)
    plt.xlabel("Generación")
    plt.ylabel("Fitness")
    plt.legend()
    plt.show()

# Gráfico de progreso de fitness (sin elitismo)
plot_fitness(generations, min_fitness_values, avg_fitness_values, "Progreso de Fitness (Sin Elitismo)")

# Gráfico de progreso de fitness (con elitismo)
plot_fitness(generations2, min_fitness_values2, avg_fitness_values2, "Progreso de Fitness (Con Elitismo)")

plot_fitness(generations_mu_lambda, min_fitness_values_mu_lambda, avg_fitness_values_mu_lambda, "Progreso de Fitness")
